# %%
# Import the needed referances
import pandas as pd
import numpy as np
import csv as csv
import matplotlib.pyplot as plt

pd.options.display.max_columns = None
pd.options.display.max_rows = 1000

# %%
mydata = pd.read_excel('Medical Data.xlsx')

# %%
mydata.head(1000)
# Out:
#      Age Sex Hypertension Diabetes Dyslipidemia           TobaccoUse  LMCA  \
# 0     58   M          Yes       No           No                   No     0
# 1     57   M          Yes       No           No                   No     0
# 2     68   F          Yes       No           No                   No     0
# 3     65   F          Yes       No           No                   No     0
# 4     62   M           No      Yes           No                   No     0
# 5     42   M           No       No           No                   No     0
# 6     49   M           No       No           No                  Yes     0
# 7     58   M          Yes      Yes           No                   No     0
# 8     56   M           No       No           No                   No     0
# 9     60   M           No       No           No                  Yes     0
# 10    50   M           No       No           No                  Yes     0
# ...

# %%
mydata.describe(include='all')
# Out:
#                 Age   Sex Hypertension Diabetes Dyslipidemia TobaccoUse  \
# count   4679.000000  4679         4677     4678         4675       4674
# unique          NaN     2            2        2            2          6
# top             NaN     M          Yes       No           No      Never
# freq            NaN  3742         2585     2908         4596       3379
# mean      60.163710   NaN          NaN      NaN          NaN        NaN
# std       10.866564   NaN          NaN      NaN          NaN        NaN
# min       20.000000   NaN          NaN      NaN          NaN        NaN
# 25%       53.000000   NaN          NaN      NaN          NaN        NaN
# 50%       61.000000   NaN          NaN      NaN          NaN        NaN
# 75%       68.000000   NaN          NaN      NaN          NaN        NaN
# max       93.000000   NaN          NaN      NaN          NaN        NaN
#
#                LMCA          RCA          LAD         CIRC      Vessel  \
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4679 entries, 0 to 4678
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           4679 non-null   int64
#  1   Sex                           4679 non-null   object
#  2   Hypertension                  4677 non-null   object
#  3   Diabetes                      4678 non-null   object
#  4   Dyslipidemia                  4675 non-null   object
#  5   TobaccoUse                    4674 non-null   object
#  6   LMCA                          4679 non-null   int64
#  7   RCA                           4679 non-null   int64
#  8   LAD                           4679 non-null   int64
#  9   CIRC                          4679 non-null   int64
#  10  Vessel                        4679 non-null   int64
#  11  Stent                         4679 non-null   int64
# ...

# %%
mydata=mydata.drop(['Unnamed: 33','Unnamed: 34','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','Unnamed: 41'],axis=1)
mydata=mydata.drop(['PreProcTnIND'],axis=1) # As all values are yes
mydata["TobaccoUse"].replace({"Current - Every Day":'Yes',"Never":'No',"Current - Some Days":'Yes'}, inplace=True) # Replacing in TobaccoUse

# %%
mydata.isna().sum().to_excel("NumberOfNulls.xlsx"),#index=False)
# Out:
# (None,)

# %%
mydata = mydata.iloc[804:]
mydata
# Out:
#       Age Sex Hypertension Diabetes Dyslipidemia TobaccoUse  LMCA  RCA  LAD  \
# 804    55   M           No       No           No        Yes     0    1    0
# 805    63   F          Yes       No           No         No     0    0    1
# 806    41   M          Yes       No           No         No     0    0    1
# 807    40   M           No       No           No         No     0    1    0
# 808    63   M           No      Yes           No         No     0    1    0
# ...   ...  ..          ...      ...          ...        ...   ...  ...  ...
# 4674   66   M           No      Yes           No         No     0    1    1
# 4675   58   M          Yes       No           No         No     0    1    0
# 4676   53   M          Yes      Yes           No        Yes     0    1    1
# 4677   58   M           No       No           No         No     0    0    1
# 4678   50   M           No      Yes           No         No     0    1    1
#
# ...

# %%
ObjCol = ['Sex', 'Hypertension', 'Diabetes', 'Dyslipidemia', 'TobaccoUse', 'PriorPCI', 'PriorCABG', 'HxHF', 'PreProcMedAdmin-Aspirin', 'PreProcMedAdmin-Beta Blocker', 'PreProcMedAdmin-Statin', 'AccessSite', 'PreProcTnTND', 'Dominance', 'PCIStatus', 'PCIIndication', 'Dischage Status']

# %%
Desc=mydata.describe(include='all').iloc[2].to_frame()
Desc['index']=Desc.index

# %%
Desc
# Out:
#                                      top                         index
# Age                                  NaN                           Age
# Sex                                    M                           Sex
# Hypertension                         Yes                  Hypertension
# Diabetes                              No                      Diabetes
# Dyslipidemia                          No                  Dyslipidemia
# TobaccoUse                            No                    TobaccoUse
# LMCA                                 NaN                          LMCA
# RCA                                  NaN                           RCA
# LAD                                  NaN                           LAD
# CIRC                                 NaN                          CIRC
# Vessel                               NaN                        Vessel
# Stent                                NaN                         Stent
# ...

# %%
# top=dict(zip(Desc.index, Desc.top))
# top

# %%
# for col in ObjCol:
#     mydata[col].fillna(top[col], inplace=True) 

# 804

mydata = mydata.fillna(-1)

# %%
mydata.to_excel("Medical Data(Updated Columns).xlsx",index=False)

# %%
from collections import Counter

letter_counts = Counter(mydata.PCIIndication)
df = pd.DataFrame.from_dict(letter_counts, orient='index')
df.plot(kind='bar')
plt.ylabel('Frequency of occurrence')
plt.xlabel('Categories')

# import matplotlib.pyplot as plt
# pd.Series(mydata.PCIStatus).value_counts().plot('bar')
# Out:
# Text(0.5, 0, 'Categories')

# %%
mydata.PCIStatus
